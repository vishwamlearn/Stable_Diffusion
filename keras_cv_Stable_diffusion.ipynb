# %%
# !pip install keras-cv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 55.5 MB/s eta 0:00:00
# ...

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")

# %%
model = keras_cv.models.StableDiffusion(
    img_width=512, img_height=512, jit_compile=False)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
prompt = "image from wind screen of car showing trucks and motorcyles running ahead"

# %%
images = model.text_to_image(prompt, batch_size=3)
# Out:
# ...
# 198180272/198180272 [==============================] - 1s 0us/step

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)

# %%
prompt = "astronaut riding sports bike on moon"
images1 = model.text_to_image(prompt, batch_size=3)
# Out:
# 50/50 [==============================] - 122s 2s/step

# %%
def plot_images(images1):
    plt.figure(figsize=(20, 20))
    for i in range(len(images1)):
        ax = plt.subplot(1, len(images1), i + 1)
        plt.imshow(images1[i])
        plt.axis("off")


plot_images(images1)
